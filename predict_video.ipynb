# %%
# !pip install ultralytics
from ultralytics import YOLO
import os
import cv2
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !nvidia-smi
# Out:
# Wed Dec  4 12:55:03 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.03                 Driver Version: 566.03         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   60C    P0             12W /   50W |     333MiB /   4096MiB |     12%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
print(os.getcwd())
model = YOLO("YOLOv8_vehicle_detection/code/runs/detect/train4/weights/best.pt")
model_pretrained = YOLO('yolov8m.pt')
# Out:
# YOLOv8_vehicle_detection

# %%
# cap = cv2.VideoCapture(video_path)
# ret, frame = cap.read()
# H, W, _ = frame.shape
# out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

# %%
# threshold = 0.5
# while ret:

#     results = model(frame)[0]

#     for result in results.boxes.data.tolist():
#         x1, y1, x2, y2, score, class_id = result

#         if score > threshold:
#             cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
#             cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
#                         cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2, cv2.LINE_AA)

#     out.write(frame)
#     ret, frame = cap.read()

# %%
# cap.release()
# out.release()
# cv2.destroyAllWindows()

# %%
def predict_video(video_path, video_path_out, model):
  cap = cv2.VideoCapture(video_path)
  ret, frame = cap.read()
  H, W, _ = frame.shape
  out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

  threshold = 0.5
  while ret:

      results = model(frame)[0]

      for result in results.boxes.data.tolist():
          x1, y1, x2, y2, score, class_id = result
          if(results.names[int(class_id)].lower() != 'car'):
              continue

          if score > threshold:
              cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 255), 3)
              cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                          cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 1, cv2.LINE_AA)

      out.write(frame)
      ret, frame = cap.read()
  cap.release()
  out.release()
  cv2.destroyAllWindows()

# %%
video_path = "C:/Users/range/OneDrive/Desktop/ML/Projects/YOLOv8_vehicle_detection/Videos/clip_1.mp4"
video_path_out = "C:/Users/range/OneDrive/Desktop/ML/Projects/YOLOv8_vehicle_detection/Videos/clip_1_out_custom.mp4".format(video_path)
predict_video(video_path, video_path_out, model)
# Out:
# 0: 384x640 5 cars, 1 two_wheeler, 63.0ms
# Speed: 9.0ms preprocess, 63.0ms inference, 2583.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 two_wheeler, 14.0ms
# Speed: 4.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 two_wheeler, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 two_wheeler, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 two_wheeler, 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 two_wheeler, 16.0ms
# Speed: 5.0ms preprocess, 16.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 two_wheeler, 19.0ms
# ...

# %%
video_path_out_pretrained = "C:/Users/range/OneDrive/Desktop/ML/Projects/YOLOv8_vehicle_detection/Videos/clip_1_out_pretrained.mp4".format(video_path)
predict_video(video_path, video_path_out_pretrained, model_pretrained)
# Out:
# 0: 384x640 3 persons, 9 cars, 1 traffic light, 135.0ms
# Speed: 4.0ms preprocess, 135.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10 cars, 38.0ms
# Speed: 5.0ms preprocess, 38.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 9 cars, 1 traffic light, 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 cars, 2 traffic lights, 39.0ms
# Speed: 4.0ms preprocess, 39.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 cars, 38.0ms
# Speed: 3.0ms preprocess, 38.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 11 cars, 2 traffic lights, 39.0ms
# Speed: 3.0ms preprocess, 39.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 12 cars, 39.0ms
# ...

# %%
video_path = "C:/Users/range/OneDrive/Desktop/ML/Projects/YOLOv8_vehicle_detection/Videos/clip_2.mp4"
video_path_out = "C:/Users/range/OneDrive/Desktop/ML/Projects/YOLOv8_vehicle_detection/Videos/clip_2_out.mp4".format(video_path)
predict_video(video_path, video_path_out, model)
# Out:
# 0: 384x640 3 cars, 1 bus, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# ...

# %%
video_path = "YOLOv8_vehicle_detection/Videos/clip_3.mp4"
video_path_out = "YOLOv8_vehicle_detection/Videos/clip_3_out.mp4".format(video_path)
predict_video(video_path, video_path_out, model)
# Out:
# 0: 384x640 3 cars, 1 two_wheeler, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 two_wheeler, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 two_wheeler, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 two_wheeler, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 two_wheeler, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 two_wheeler, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 two_wheeler, 9.0ms
# ...
